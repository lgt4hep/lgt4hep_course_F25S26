# %% [markdown]
# # LGT1 Unit07 Day03 - Pre-Class: Determining PDFs from a Lattice QCD Inverse Problem with Machine Learning

# %% [markdown]
# ## Assignment Goals
#
# The goals of this assignment are to:
#
# * Learn the definition of an inverse problem
# * Learn how psuedo-data can be used to train models to solve the inverse problem
# * Learn the basic definition of a parton distribution function (PDF)
# * Learn how machine learning can be applied to solve the inverse problem in the psuedo-PDF method for calculating PDFs from lattice QCD
#
# ## Assignment Instructions
# Please complete this assignment and submit your notebook to GradeScope prior to the start of our class.

# %% [markdown]
# ---
# # A Quick Lecture!
# For today's pre-class notebook, please watch the short lecture video (< 10 mins) below and then answer the questions below. In this video, we will briefly learn what an inverse problem is and why it plays a central role in many areas of physics.  To provide the necessary physics background, we will also review the basic definition of a parton distribution function (PDF). We will then explore how pseudo-data can be generated and used to train models capable of solving such inverse problems. Finally, we will examine how machine learning techniques can be applied to address the inverse problem specifically within the pseudo-PDF approach for extracting PDFs from lattice QCD.

# %%
from IPython.display import YouTubeVideo
def fix_repr_html_(self):
  original_html = super(YouTubeVideo, self)._repr_html_()
  new_html      = original_html.replace(
    '<iframe',
    '<iframe referrerpolicy ="strict-origin-when-cross-origin"')
  return new_html

YouTubeVideo._repr_html_ = fix_repr_html_

YouTubeVideo("TXZAYKf9_jA",width=640,height=340)
# Direct Link: https://youtu.be/TXZAYKf9_jA

# %% [markdown]
# As a quick recap from your pre-class lecture, we will use the pseudo-PDF matching relation to generate the data for training our CNN:
#
# $$ \tag{1}
# \mathcal{M}(\nu = z \cdot P_z, z^2) = \int_0^1 dx \; \frac{x g(x, \mu^2)}{\langle x \rangle_g (\mu^2)} R_{gg}(\nu x, \mu^2 z^2)
# $$
#
# Here, $\nu = z \cdot P_z$, is referred to as the Ioffe-time, $xg(x, \mu^2) / \langle x \rangle_g(\mu^2)$ is the normalized gluon PDF, and $R_{gg}(\nu x, \mu^2 z^2)$ is the matching kernel dervied from perturbative QCD. We will not delve into the details of the kernel in this lecture, but interested students can refer to the literature for more information:
# * [Radyushkin, PRD 96:034025 (2017)](https://journals.aps.org/prd/abstract/10.1103/PhysRevD.96.034025)
# * [Balitsky, et al., PLB 808:135621 (2020)](https://scoap3-prod-backend.s3.cern.ch/media/files/55734/10.1016/j.physletb.2020.135621.pdf)
#
#
# For generating training data, we will sample from the empirical PDF model
#
# $$ \tag{2}
# \frac{xg(x,\mu^2)}{\langle x \rangle_g(\mu^2)} = x^\alpha (1-x)^\beta (1 + \gamma x + \delta \sqrt{x})
# $$
#
# by varying the parameters ($\alpha$, $\beta$, $\gamma$, $\delta$), which will allow us to produce a broad set of pseudo-PDFs for training our CNN.

# %% [markdown]
# ### Task: Check Your Understanding
# After watching the pre-class lecture, answer the following questions:
# * In your own words, what are parton distribution functions and what's one reason we're interested in determining them?
# * Describe an inverse problem from your own research or do a quick search to find an inverse problem in a field of research you're interested in. What makes this an inverse problem?
# * Briefly describe how we plan to solve our inverse problem with machine learning.

# %% [markdown]
# [your answer here]

# %% [markdown]
# ---
# # Assignment Complete!
#
# Please fill out the Google Form below and then submit your notebook to [GradeScope](https://www.gradescope.com/courses/1092386) prior to the start of our class!

# %%
from IPython.display import HTML
HTML(
"""
<iframe
	src="https://forms.gle/Y66wJvJptRiXwD4E9"
	width="80%"
	height="1200px"
	frameborder="0"
	marginheight="0"
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://forms.gle/Y66wJvJptRiXwD4E9"
# 	width="80%"
# 	height="1200px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>
